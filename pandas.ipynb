# %%
import pandas as pd

exam_scores = pd.read_csv('C:/Users/adeay/OneDrive/Documents/exam_scores.csv')

# %%
exam_scores.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2    male        group C                some college  free/reduced
# 3  female        group D           bachelor's degree  free/reduced
# 4    male        group D                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          74             68             67
# 1               completed          58             68             66
# 2                    none          66             65             65
# 3                    none          74             75             73
# 4                    none          78             77             71

# %%
exam_scores.shape
# Out:
# (1000, 8)

# %%
exam_scores.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2    male        group C                some college  free/reduced
# 3  female        group D           bachelor's degree  free/reduced
# 4    male        group D                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          74             68             67
# 1               completed          58             68             66
# 2                    none          66             65             65
# 3                    none          74             75             73
# 4                    none          78             77             71

# %%
exam_scores.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group C            some high school      standard
# 996  female        group E                some college      standard
# 997  female        group E          associate's degree  free/reduced
# 998  female        group C                 high school      standard
# 999    male        group C                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995                    none          68             77             72
# 996                    none          98             81             94
# 997                    none          67             67             67
# 998                    none          63             68             70
# 999                    none          49             57             50

# %%
exam_scores.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
exam_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
exam_scores.iloc[0,0]
# Out:
# 'male'

# %%
exam_scores.iloc[0:5, 4]
# Out:
# 0         none
# 1    completed
# 2         none
# 3         none
# 4         none
# Name: test preparation course, dtype: object

# %%
exam_scores.iloc[:,:]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2      male        group C                some college  free/reduced
# 3    female        group D           bachelor's degree  free/reduced
# 4      male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group C            some high school      standard
# 996  female        group E                some college      standard
# 997  female        group E          associate's degree  free/reduced
# 998  female        group C                 high school      standard
# 999    male        group C                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          74             68             67
# 1                 completed          58             68             66
# 2                      none          66             65             65
# 3                      none          74             75             73
# 4                      none          78             77             71
# ..                      ...         ...            ...            ...
# 995                    none          68             77             72
# 996                    none          98             81             94
# 997                    none          67             67             67
# 998                    none          63             68             70
# 999                    none          49             57             50
#
# [1000 rows x 8 columns]

# %%
exam_scores.iloc[-5:, :2]
# Out:
#      gender race/ethnicity
# 995  female        group C
# 996  female        group E
# 997  female        group E
# 998  female        group C
# 999    male        group C

# %%
exam_scores.gender
# Out:
# 0        male
# 1      female
# 2        male
# 3      female
# 4        male
#         ...
# 995    female
# 996    female
# 997    female
# 998    female
# 999      male
# Name: gender, Length: 1000, dtype: object

# %%
exam_scores["gender"]
# Out:
# 0        male
# 1      female
# 2        male
# 3      female
# 4        male
#         ...
# 995    female
# 996    female
# 997    female
# 998    female
# 999      male
# Name: gender, Length: 1000, dtype: object

# %%
exam_scores[exam_scores.gender == 'female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 3    female        group D           bachelor's degree  free/reduced
# 5    female        group D          associate's degree      standard
# 6    female        group B          associate's degree  free/reduced
# 10   female        group E                some college  free/reduced
# ..      ...            ...                         ...           ...
# 990  female        group D                 high school      standard
# 995  female        group C            some high school      standard
# 996  female        group E                some college      standard
# 997  female        group E          associate's degree  free/reduced
# 998  female        group C                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# 1                 completed          58             68             66
# 3                      none          74             75             73
# 5                 completed          75             82             85
# 6                      none          69             78             80
# 10                     none          64             69             65
# ..                      ...         ...            ...            ...
# 990                    none          46             54             53
# 995                    none          68             77             72
# 996                    none          98             81             94
# 997                    none          67             67             67
# 998                    none          63             68             70
#
# [502 rows x 8 columns]

# %%
##summary functions

# %%
exam_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
exam_scores.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000     1000.00000    1000.000000
# mean     67.128000       70.17400      68.973000
# std      14.815367       14.85599      15.109155
# min      15.000000       18.00000      10.000000
# 25%      58.000000       60.00000      59.000000
# 50%      67.000000       70.00000      69.000000
# 75%      78.000000       81.00000      80.000000
# max     100.000000      100.00000     100.000000

# %%
exam_scores.describe(include = 'object')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       502            294                         226       649
#
#        test preparation course
# count                     1000
# unique                       2
# top                       none
# freq                       654

# %%
exam_scores.describe(include = "all")
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       502            294                         226       649
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course   math score  reading score  writing score
# count                     1000  1000.000000     1000.00000    1000.000000
# unique                       2          NaN            NaN            NaN
# top                       none          NaN            NaN            NaN
# freq                       654          NaN            NaN            NaN
# mean                       NaN    67.128000       70.17400      68.973000
# std                        NaN    14.815367       14.85599      15.109155
# min                        NaN    15.000000       18.00000      10.000000
# 25%                        NaN    58.000000       60.00000      59.000000
# 50%                        NaN    67.000000       70.00000      69.000000
# 75%                        NaN    78.000000       81.00000      80.000000
# max                        NaN   100.000000      100.00000     100.000000

# %%
##aggregate functions

# %%
exam_scores.mean()
# Out:
# C:\Users\adeay\AppData\Local\Temp\ipykernel_7484\3785189124.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   exam_scores.mean()
# math score       67.128
# reading score    70.174
# writing score    68.973
# dtype: float64

# %%
exam_scores.gender.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
exam_scores.gender.value_counts()
# Out:
# female    502
# male      498
# Name: gender, dtype: int64

# %%
##Sorting

# %%
exam_scores.sort_values(by = 'math score').head()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 949    male        group C                 high school  free/reduced
# 854    male        group C                 high school  free/reduced
# 891  female        group C                 high school  free/reduced
# 349    male        group B            some high school  free/reduced
# 739  female        group E            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 949                    none          15             18             10
# 854                    none          18             30             18
# 891                    none          23             31             27
# 349                    none          25             31             30
# 739                    none          25             35             38

# %%
exam_scores.sort_values(by = 'math score', ascending = False).head()
# Out:
#     gender race/ethnicity parental level of education     lunch  \
# 91    male        group D          associate's degree  standard
# 776   male        group E          associate's degree  standard
# 588   male        group D                some college  standard
# 128   male        group A          associate's degree  standard
# 565   male        group E           bachelor's degree  standard
#
#     test preparation course  math score  reading score  writing score
# 91                     none         100             94             96
# 776               completed         100            100            100
# 588               completed         100             85             91
# 128               completed         100             97             94
# 565               completed         100            100            100

# %%
exam_scores['math score'].sort_values(ascending = False)[:5]
# Out:
# 91     100
# 776    100
# 588    100
# 128    100
# 565    100
# Name: math score, dtype: int64

# %%
##renaming

# %%
exam_scores.rename(columns = {"race/ethnicity": "race",
                             "parental level of education": "parent_level_education",
                             "test preparation course": "preparation_course",
                             "math score": 'math_score',
                             'reading score':'reading_score',
                             'writing score': 'writing_score'}, inplace = True)

# %%
exam_scores.head()
# Out:
#    gender     race parent_level_education         lunch preparation_course  \
# 0    male  group B      bachelor's degree      standard               none
# 1  female  group C           some college      standard          completed
# 2    male  group C           some college  free/reduced               none
# 3  female  group D      bachelor's degree  free/reduced               none
# 4    male  group D           some college      standard               none
#
#    math_score  reading_score  writing_score
# 0          74             68             67
# 1          58             68             66
# 2          66             65             65
# 3          74             75             73
# 4          78             77             71

# %%
##missing values

# %%
exam_scores.isnull().sum()
# Out:
# gender                    0
# race                      0
# parent_level_education    0
# lunch                     0
# preparation_course        0
# math_score                0
# reading_score             0
# writing_score             0
# dtype: int64
